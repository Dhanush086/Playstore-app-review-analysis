# %% [markdown]
# # **Project Name**    - Play Store App Review Analysis

# %% [markdown]
# ##### **Project Type**    - ED
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The Play Store App Review Analysis project focuses on analyzing app metadata and user review data using Exploratory Data Analysis (EDA) to identify patterns related to app performance, pricing, and user sentiment. The dataset is cleaned by handling missing values, removing duplicates, correcting a corrupted row, and converting text-based fields into proper numeric types to ensure accurate analysis.
#
# Various visualizations such as bar charts, histograms, box plots, scatter plots, heatmaps, and pair plots are used to explore app categories, pricing models, installs, ratings, and review sentiment. These analyses help identify which categories dominate the market, whether pricing affects user satisfaction, how review sentiment relates to official ratings, and what factors are (and aren't) associated with higher app ratings.
#
# The project is implemented using Python and libraries such as Pandas, NumPy, Matplotlib, and Seaborn, within Google Colab. Overall, the project demonstrates how EDA helps understand what drives app success on the Play Store, improves data quality, and provides meaningful insights that support better business decisions around category selection, pricing strategy, and user experience investment.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Dhanush086

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# ## Problem Statement
#
# The Google Play Store hosts millions of apps competing for user attention, but success is not evenly distributed — some apps achieve high ratings and massive install bases, while similar apps struggle with poor reviews and low adoption. Developers and product teams often lack clear, data-backed insight into what actually drives this difference: is it category, pricing, app size, or how well the app resonates with users in their written feedback?
#
# This project analyzes Play Store app metadata and user reviews to identify the key factors influencing app ratings, installs, and user sentiment, and to understand where star ratings alone may be an incomplete or misleading signal of true user satisfaction.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The objective of this analysis is to help app developers and product teams make data-driven decisions on category positioning, pricing strategy, and user experience, based on Google Play Store app data and user reviews. It aims to identify which categories offer real opportunity versus heavy competition, whether pricing affects app ratings and adoption, and whether star ratings alone reliably reflect user satisfaction — turning raw data into actionable recommendations a business can use.

# %% [markdown]
# ## Business Objective
# The objective of this analysis is to help app developers and product teams make data-driven decisions on category positioning, pricing strategy, and user experience — based on Google Play Store app data and user reviews.
# Specifically, the analysis aims to:
#
# Identify strong vs. saturated categories — where should a business compete
#
#
#
# * identify strong vs. saturated categories — where should a business compete based on ratings and installs?
# * Guide pricing strategy — do free or paid apps perform better in terms of ratings and adoption?
# * Validate ratings against real user sentiment — do star ratings reflect what users actually say in reviews, or are there hidden satisfaction/dissatisfaction signals ratings miss?
# * Flag risk areas — which categories show high negative sentiment, signaling potential product or UX issues before they hurt retention?
#
#
# The end goal is to turn raw app store data into practical, actionable recommendations a business can use to improve app performance and user satisfaction — not just descriptive charts.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd

from numpy import loadtxt
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import rcParams

# !pip install pymysql
import pymysql
from sqlalchemy import create_engine
from sqlalchemy.pool import NullPool

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
apps_df = pd.read_csv('/content/drive/MyDrive/Play Store Data.csv')
reviews_df = pd.read_csv('/content/drive/MyDrive/User Reviews.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
apps_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
reviews_df.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
apps_df.shape
# Out:
# (10841, 13)

# %%
reviews_df.shape
# Out:
# (64295, 5)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
apps_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
# Check duplicates
print("Duplicate rows in apps_df:", apps_df.duplicated().sum())
print("Duplicate rows in reviews_df:", reviews_df.duplicated().sum())

# Apps are also often duplicated by name (same app listed multiple times)
print("Duplicate App names in apps_df:", apps_df['App'].duplicated().sum())
# Out:
# Duplicate rows in apps_df: 483
# Duplicate rows in reviews_df: 33616
# Duplicate App names in apps_df: 1181

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print("missing values in apps_df",apps_df.isnull().sum())
# Out:
# missing values in apps_df App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
print("missing values in review_df",reviews_df.isnull().sum())
# Out:
# missing values in review_df App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
# Visualizing the missing values
plt.figure(figsize=(10, 6))
sns.heatmap(apps_df.isnull(), cbar=False, cmap='viridis',yticklabels=False)
plt.title('Missing Values Heatmap')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(reviews_df.isnull(),cbar=False,cmap='viridis',yticklabels=False)
plt.title('missing values heatmap')
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# This dataset is from the Google Play Store, and the goal is to analyze app performance and user reviews to understand what drives ratings, installs, and sentiment across app categories.
#
# There are two related datasets. apps_df has 10,841 rows and 13 columns, where each row represents one app. reviews_df has 64,295 rows and 5 columns, where each row represents one individual review — this is why reviews_df has far more rows than apps_df, since a single app can receive hundreds of reviews.
#
# In apps_df, most columns are stored as text (object), including some that should actually be numeric — Reviews, Size, Installs, and Price — these will need to be converted before any numeric analysis.
#
# Both datasets contain duplicate rows — 483 in apps_df and 33,616 in reviews_df — which will need to be removed before analysis to avoid double-counting.
#
# For missing values, apps_df has a notable gap only in Rating 1,474 missing . In reviews_df, Translated_Review, Sentiment, Sentiment_Polarity, and Sentiment_Subjectivity are all missing together in the same ~26,863 rows — because when a user doesn't write review text, there's nothing for a sentiment tool to analyze, so all sentiment-related fields stay empty for that row too.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
apps_df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
reviews_df.columns
# Out:
# Index(['App', 'Translated_Review', 'Sentiment', 'Sentiment_Polarity',
#        'Sentiment_Subjectivity'],
#       dtype='object')

# %%
# Dataset Describe
apps_df.describe(include='all')
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %%
reviews_df.describe(include='all')
# Out:
#                App Translated_Review Sentiment  Sentiment_Polarity  \
# count        64295             37427     37432        37432.000000
# unique        1074             27994         3                 NaN
# top     Bowmasters              Good  Positive                 NaN
# freq           320               247     23998                 NaN
# mean           NaN               NaN       NaN            0.182146
# std            NaN               NaN       NaN            0.351301
# min            NaN               NaN       NaN           -1.000000
# 25%            NaN               NaN       NaN            0.000000
# 50%            NaN               NaN       NaN            0.150000
# 75%            NaN               NaN       NaN            0.400000
# max            NaN               NaN       NaN            1.000000
#
#         Sentiment_Subjectivity
# count             37432.000000
# unique                     NaN
# top                        NaN
# freq                       NaN
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# ##apps_df (App metadata)
#
#
# *  App-      Name of the application
# *  Category- The category/genre the app is classified under (e.g., Games, Tools, Social)
# *  Rating-Average user rating of the app, out of 5
# *  Reviews-Total number of user reviews the app has received
# * Size-Size of the app installation file (in MB, or "Varies with device")
# * installs-Number of times the app has been installed (approximate, bucketed values like "10,000+")
# * Type-Whether the app is Free or Paid
# * Price-Price of the app in USD (0 if free)
# * content Rating-Age-based content classification (e.g., Everyone, Teen, Mature 17+)
# * GenresMore specific sub-category than Category (an app can belong to multiple genres)
# * Last Updated-Date the app was last updated on the Play Store
# * Current Ver-Current version number of the app
# * Android Ver-Minimum Android OS version required to run the app
#
#
# ##reviews_df (User reviews)
# * App-Name of the app the review belongs to
# * Translated_Review-The review text written by the user (translated to English)
# * Sentiment-Overall sentiment of the review — Positive, Negative, or Neutral
# * Sentiment_Polarity-Numeric score from -1 (very negative) to +1 (very positive), indicating sentiment strength
# * sentiment_Subjectivity-Numeric score from 0 (very objective/factual) to 1 (very subjective/opinion-based)

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in apps_df.columns.tolist():
  print("no of unique values in",i,"is",apps_df[i].nunique(),".")
# Out:
# no of unique values in App is 9660 .
# no of unique values in Category is 34 .
# no of unique values in Rating is 40 .
# no of unique values in Reviews is 6002 .
# no of unique values in Size is 462 .
# no of unique values in Installs is 22 .
# no of unique values in Type is 3 .
# no of unique values in Price is 93 .
# no of unique values in Content Rating is 6 .
# no of unique values in Genres is 120 .
# no of unique values in Last Updated is 1378 .
# no of unique values in Current Ver is 2832 .
# no of unique values in Android Ver is 33 .

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# %%
# Check unique values in Type column
apps_df["Type"].unique()
# Out:
# array(['Free', 'Paid', nan, '0'], dtype=object)

# %%
# Identify the corrupted row by filtering for Type == '0'
# '0' is not a valid value for Type (should only be 'Free' or 'Paid'),
# so this filter helps us locate the exact row causing the issue
apps_df[apps_df['Type'] == '0']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
## Remove the row where Type == '0' (the corrupted row)
apps_df = apps_df[apps_df['Type'] != '0']
# Confirm the row is removed - shape should now be one row less than original
print(apps_df.shape)
# Out:
# (10840, 13)

# %%
# Remove exact duplicate rows (all columns identical)
apps_df=apps_df.drop_duplicates()
# Confirm shape after removing exact duplicates
print(apps_df.shape)
# Out:
# (10357, 13)

# %%
# Remove apps that repeat by name (keep first occurrence)
apps_df=apps_df.drop_duplicates(subset='App')
print(apps_df.shape)
# Out:
# (9659, 13)

# %%
# Reviews column has number-like text (e.g., "967") - convert it to actual integers
apps_df['Reviews']=apps_df['Reviews'].astype(int)
# Confirm the conversion worked - dtype should now be int, not object
print(apps_df['Reviews'].dtype)
# Out:
# int64

# %%
# Remove '+' and ',' symbol from Installs column
apps_df['Installs']=apps_df["Installs"].str.replace("+","").str.replace(",","")
apps_df['Installs']
# Out:
# 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
#            ...
# 10836        5000
# 10837         100
# 10838        1000
# 10839        1000
# 10840    10000000
# Name: Installs, Length: 9659, dtype: object

# %%
# Convert cleaned Installs column to integer type
apps_df["Installs"]=apps_df["Installs"].astype(int)
# Confirm conversion worked
apps_df["Installs"].dtype
# Out:
# dtype('int64')

# %%
# Remove '$' symbol from Price column
apps_df["Price"] = apps_df["Price"].str.replace("$", "")

# %%
# Convert cleaned Price column to float (keeps decimal values like 4.99)
apps_df["Price"] = apps_df["Price"].astype(float)

# %%
# Confirm conversion worked
apps_df["Price"].dtype
# Out:
# dtype('float64')

# %%
# Remove 'k' and 'm'  from Size column and convert everything into same size
def convert_size(x):
    if x.endswith("k"):
        x = x.replace("k", "")
        x = float(x)
        return x / 1000
    elif x.endswith("M"):
        x = x.replace("M", "")
        x = float(x)
        return x
    else:
        return np.nan
#Apply convert_size function to every value in the Size column
apps_df["Size"]=apps_df["Size"].apply(convert_size)

# %%
# Confirm the conversion worked
apps_df["Size"].dtype
apps_df["Size"].head(10)
# Out:
# 0    19.0
# 1    14.0
# 2     8.7
# 3    25.0
# 4     2.8
# 5     5.6
# 6    19.0
# 7    29.0
# 8    33.0
# 9     3.1
# Name: Size, dtype: float64

# %%
# Convert Last Updated column from text to actual datetime type
apps_df["Last Updated"]=pd.to_datetime(apps_df["Last Updated"])
#con

# %%
#check the conversion worked
apps_df["Last Updated"].dtype
apps_df["Last Updated"].head(10)
# Out:
# 0   2018-01-07
# 1   2018-01-15
# 2   2018-08-01
# 3   2018-06-08
# 4   2018-06-20
# 5   2017-03-26
# 6   2018-04-26
# 7   2018-06-14
# 8   2017-09-20
# 9   2018-07-03
# Name: Last Updated, dtype: datetime64[ns]

# %%
# Fill missing Rating values with the median (not mean), since Rating is skewed
# by a small number of very low ratings - median is more robust to outliers
apps_df['Rating']=apps_df['Rating'].fillna(apps_df["Rating"].median())

# Confirm no missing values remain in Rating
apps_df['Rating'].isnull().sum()
# Out:
# np.int64(0)

# %%
# Fill missing Size values with median, since Size is right-skewed by a few large apps
apps_df['Size']=apps_df['Size'].fillna(apps_df["Size"].median())
#confirm no missing values remain in size
apps_df['Size'].isnull().sum()
# Out:
# np.int64(0)

# %%
# Remove exact duplicate rows in reviews_df
reviews_df=reviews_df.drop_duplicates()
#confirm shape after removing duplicates
reviews_df.shape
# Out:
# (30679, 5)

# %%
#which category has the most apps
apps_df['Category'].value_counts()
# Out:
# Category
# FAMILY                 1832
# GAME                    959
# TOOLS                   827
# BUSINESS                420
# MEDICAL                 395
# PERSONALIZATION         376
# PRODUCTIVITY            374
# LIFESTYLE               369
# FINANCE                 345
# SPORTS                  325
# COMMUNICATION           315
# HEALTH_AND_FITNESS      288
# PHOTOGRAPHY             281
# NEWS_AND_MAGAZINES      254
# SOCIAL                  239
# BOOKS_AND_REFERENCE     222
# TRAVEL_AND_LOCAL        219
# SHOPPING                202
# DATING                  171
# VIDEO_PLAYERS           163
# MAPS_AND_NAVIGATION     131
# EDUCATION               119
# FOOD_AND_DRINK          112
# ENTERTAINMENT           102
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       84
# WEATHER                  79
# HOUSE_AND_HOME           74
# ART_AND_DESIGN           64
# EVENTS                   64
# PARENTING                60
# COMICS                   56
# ...

# %%
# Get today's date
today = pd.to_datetime('today')
print(today)
# Out:
# 2026-07-28 06:45:45.014977

# %%
# Create a new column: number of days since the app was last updated
apps_df['Days_Since_Update'] = (today - apps_df['Last Updated']).dt.days
# Check the result
apps_df[['App', 'Last Updated', 'Days_Since_Update']].head()
# Out:
#                                                  App Last Updated  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook   2018-01-07
# 1                                Coloring book moana   2018-01-15
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...   2018-08-01
# 3                              Sketch - Draw & Paint   2018-06-08
# 4              Pixel Draw - Number Art Coloring Book   2018-06-20
#
#    Days_Since_Update
# 0               3124
# 1               3116
# 2               2918
# 3               2972
# 4               2960

# %%
# Merge reviews_df and apps_df on the shared 'App' column
# This combines review-level data (text, sentiment) with app-level data (category, rating, installs)
merged_df = reviews_df.merge(apps_df, on='App')

# Check the result
print(merged_df.shape)
merged_df.head()
# Out:
# (29190, 18)
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity            Category  \
# 0  Positive                1.00                0.533333  HEALTH_AND_FITNESS
# 1  Positive                0.25                0.288462  HEALTH_AND_FITNESS
# 2       NaN                 NaN                     NaN  HEALTH_AND_FITNESS
# 3  Positive                0.40                0.875000  HEALTH_AND_FITNESS
# 4  Positive                1.00                0.300000  HEALTH_AND_FITNESS
#
# ...

# %%
# Check average official Rating for each review Sentiment group
merged_df.groupby('Sentiment')['Rating'].mean()
# Out:
# Sentiment
# Negative    4.250751
# Neutral     4.218433
# Positive    4.320022
# Name: Rating, dtype: float64

# %%
# check Free apps get better ratings than Paid apps.
merged_df.groupby('Type')['Rating'].mean()
# Out:
# Type
# Free    4.290167
# Paid    4.303774
# Name: Rating, dtype: float64

# %%
merged_df.groupby('Category')['Installs'].mean().sort_values(ascending=False)
# Out:
# Category
# SOCIAL                 2.282470e+08
# COMMUNICATION          1.303527e+08
# PHOTOGRAPHY            1.241650e+08
# NEWS_AND_MAGAZINES     6.684491e+07
# TOOLS                  6.523771e+07
# PRODUCTIVITY           5.036386e+07
# GAME                   4.537171e+07
# BOOKS_AND_REFERENCE    3.359358e+07
# SHOPPING               2.289235e+07
# WEATHER                1.687000e+07
# PERSONALIZATION        1.561175e+07
# TRAVEL_AND_LOCAL       1.541173e+07
# VIDEO_PLAYERS          1.539403e+07
# FAMILY                 1.215958e+07
# EDUCATION              9.948961e+06
# ENTERTAINMENT          9.362194e+06
# BUSINESS               8.507953e+06
# HEALTH_AND_FITNESS     5.662372e+06
# FINANCE                5.010109e+06
# SPORTS                 4.740289e+06
# LIFESTYLE              4.240163e+06
# FOOD_AND_DRINK         2.937396e+06
# MAPS_AND_NAVIGATION    2.050000e+06
# ART_AND_DESIGN         2.019699e+06
# LIBRARIES_AND_DEMO     1.976979e+06
# AUTO_AND_VEHICLES      1.567123e+06
# ...

# %%
apps_df.columns.tolist()
# Out:
# ['App',
#  'Category',
#  'Rating',
#  'Reviews',
#  'Size',
#  'Installs',
#  'Type',
#  'Price',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver',
#  'Days_Since_Update']

# %%
# Sort apps by Installs (highest first) to see the top 10 most installed apps
apps_df.sort_values(by='Installs', ascending=False).head(10)
# Out:
#                           App             Category  Rating   Reviews  Size  \
# 3736              Google News   NEWS_AND_MAGAZINES     3.9    877635  13.0
# 2554                  Google+               SOCIAL     4.2   4831125  12.0
# 1654           Subway Surfers                 GAME     4.5  27722264  76.0
# 152         Google Play Books  BOOKS_AND_REFERENCE     3.9   1433233  12.0
# 3665                  YouTube        VIDEO_PLAYERS     4.3  25655305  12.0
# 2545                Instagram               SOCIAL     4.5  66577313  12.0
# 3687  Google Play Movies & TV        VIDEO_PLAYERS     3.7    906384  12.0
# 2808            Google Photos          PHOTOGRAPHY     4.5  10858556  12.0
# 3127       Google Street View     TRAVEL_AND_LOCAL     4.2   2129689  12.0
# 865         Google Play Games        ENTERTAINMENT     4.3   7165362  12.0
#
#         Installs  Type  Price Content Rating                   Genres  \
# 3736  1000000000  Free    0.0           Teen         News & Magazines
# ...

# %%
#Apps have the highest number of Reviews
apps_df.sort_values(by='Reviews', ascending=False).head(10)
# Out:
#                                                     App       Category  \
# 2544                                           Facebook         SOCIAL
# 336                                  WhatsApp Messenger  COMMUNICATION
# 2545                                          Instagram         SOCIAL
# 335            Messenger – Text and Video Chat for Free  COMMUNICATION
# 1670                                     Clash of Clans           GAME
# 4005            Clean Master- Space Cleaner & Antivirus          TOOLS
# 1654                                     Subway Surfers           GAME
# 3665                                            YouTube  VIDEO_PLAYERS
# 7536  Security Master - Antivirus, VPN, AppLock, Boo...          TOOLS
# 1660                                       Clash Royale           GAME
#
#       Rating   Reviews  Size    Installs  Type  Price Content Rating  \
# 2544     4.1  78158306  12.0  1000000000  Free    0.0           Teen
# ...

# %% [markdown]
# ## What all manipulations have you done and insights you found?
#
#
# ##**Manipulations Performed:**
# ###In apps_df:
# * Removed 1 corrupted row where all column values were shifted left due to a scraping error (flagged by an invalid Type = '0')
# * Removed 483 exact duplicate rows, then removed rows with repeated App names — reducing the dataset from 10,841 to 9,659 unique apps
# * Converted Reviews, Installs, and Price from text to numeric types
# * Converted Size into a consistent numeric MB value using a custom function, since raw values mixed "M", "k", and "Varies with device"
# * Converted Last Updated from text to proper datetime format
# * Filled missing Rating and Size values using median , since both are skewed by outliers
# * Engineered a new feature, Days_Since_Update, calculating how many days have passed since each app's last update
# * Merged apps_df and reviews_df on the App column to enable cross-dataset analysis
#
# ###In reviews_df:
# * Removed 33,616 exact duplicate rows, reducing the dataset from 64,295 to 30,679 rows
# * Retained rows with missing review text/sentiment (since the App field is still valid for general analysis), to be excluded only during sentiment-specific analysis
#
#
#
# ##**Insights Found:**
# * Sentiment vs Rating: Average Rating is nearly identical across Positive (4.32), Negative (4.25), and Neutral (4.22) sentiment reviews. Negative sentiment reviews having a slightly higher rating than Neutral suggests users can complain about a specific feature while still liking the app overall — meaning star ratings alone can hide fixable pain points.
#
# * Free vs Paid pricing: Free apps (4.29 avg rating) and Paid apps (4.30 avg rating) are nearly identical — pricing model has almost no effect on user satisfaction, so monetization decisions can be made independent of rating risk.
#
# * Installs by Category: SOCIAL has the highest average installs (228M) despite having very few apps (239), skewed heavily by a handful of dominant apps (Facebook, Instagram, WhatsApp). FAMILY has the most apps (1,832) but far lower average installs (12M) — proving more apps in a category doesn't mean more installs per app.
#
# * Top Installed Apps (data limitation): The top 10 apps by installs all show the identical value (1,000,000,000), since Play Store reports installs in rounded tiers, not exact counts  meaning exact ranking within the top tier can't be determined from this data.
#
# * Top Reviewed Apps: Facebook, Instagram, and Messenger lead in review counts, confirming SOCIAL/COMMUNICATION apps dominate not just installs but user engagement — reinforcing that this category is a high-barrier, winner-take-all space for new entrants.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 Distribution of App Rating (Univariate)

# %%
# Chart - 1 visualization code
# Distribution of Rating (Univariate)
plt.figure(figsize=(8,5))
sns.histplot(apps_df['Rating'], bins=20, kde=True)
plt.title('Distribution of App Ratings')
plt.xlabel('Rating')
plt.ylabel('Number of Apps')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Rating is continuous, so histogram groups values into ranges to reveal the overall shape.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  Most apps cluster between 4.0–4.5 rating, with a left-skewed distribution — a small number of apps have much lower ratings (1.0–2.5), pulling a thin tail to the left.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive — most apps on the Play Store are well-received by users (ratings mostly 4+), suggesting the app ecosystem overall maintains decent quality. Negative/risk angle — the small cluster of very low-rated apps represents real problem apps that could hurt category reputation or user trust if not identified and addressed.

# %% [markdown]
# #### Chart - 2 Top 15 Categories by number of apps (Univariate)

# %%
# Chart - 2 visualization code
# Top 15 Categories by number of apps (Univariate)
# Using a bar chart since Category is categorical - showing only top 15 for readabilit
plt.figure(figsize=(10,6))
top_categories=apps_df['Category'].value_counts().head(15)
sns.barplot(x=top_categories.values,y=top_categories.index)
plt.title('top 15 categories by number of apps')
plt.xlabel('number of apps')
plt.ylabel('category')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Category is a categorical variable, so a bar chart makes it easy to compare how many apps exist in each category at a glance.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# FAMILY dominates with 1,750+ apps, followed by GAME (1,000+) and TOOLS (750+) — far ahead of every other category.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# his cuts both ways depending on strategy.
# *  Negative angle: FAMILY, GAME, and TOOLS are already heavily saturated — a new app entering these categories faces intense competition and will struggle to gain visibility among thousands of existing apps.
# * Positive angle: Categories further down the list (like BEAUTY, PARENTING, EVENTS) have far fewer apps — this represents lower competition and a potentially easier path to visibility, though it should be checked against demand/installs before assuming it's a good opportunity (a category might have few apps simply because few people want them).

# %% [markdown]
# #### Chart - 3  Free vs Paid apps distribution (Univariate)

# %%
# Chart - 3 visualization code
# Chart 3: Free vs Paid apps distribution (Univariate)
# Using a pie chart since Type has only 2 categories, and we want to see proportion of the whole
apps_df['Type'].value_counts().plot(kind='pie',autopct='%1.1f%%')
plt.title('free vs paid')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  Type has only two categories (Free/Paid), and a pie chart clearly shows the proportional split of the whole dataset between them.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 92.2% of apps are Free, while only 7.8% are Paid — a heavily lopsided split.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Positive angle — this confirms the dominant market norm on the Play Store is Free apps (likely monetized through ads or in-app purchases instead of upfront cost), so a new business following this model aligns with what users already expect, lowering the barrier to first-time downloads.
#
# * Negative/risk angle — launching a Paid app goes against strong user expectations (only 7.8% of the market), meaning it faces a much higher barrier to adoption; users may be less willing to pay upfront when almost every competing app is free, so a Paid strategy would need a very strong value proposition to overcome this norm.

# %% [markdown]
# #### Chart - 4 Count how many apps fall under each Content Rating category

# %%
# Chart - 4 visualization code
# Count how many apps fall under each Content Rating category
# Plot as a bar chart since Content Rating is categorical
apps_df['Content Rating'].value_counts().plot(kind='bar')
plt.title('Content Rating Distribution')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  Content Rating is a categorical variable, so a bar chart makes it easy to compare how many apps fall under each age classification.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# "Everyone" dominates with nearly 8,000 apps, far ahead of Teen, Mature 17+, and Everyone 10+ (each under 1,000 apps). Notably, "Adults only 18+" has 0 apps — this isn't a user preference signal, but most likely reflects Google Play's own platform policy, which doesn't permit explicit adult-content apps on the store at all (similar to how mainstream app stores generally exclude explicit adult content by policy, not by demand).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * the overwhelming dominance of "Everyone" apps confirms that building for the broadest possible audience is the platform norm, and gives the largest addressable market with the fewest content restrictions.
# * Risk/consideration angle — targeting a narrower content rating (Teen, Mature 17+) means competing in a much smaller pool of apps, which could mean either lower competition (an opportunity) or lower overall demand for that content type — this would need to be checked against installs data before concluding it's a good opportunity. The "0 apps in Adults 18+" finding itself is a platform policy fact, not a business opportunity or risk — it simply confirms what content types are even permitted on this platform.

# %% [markdown]
# #### Chart - 5 Box plot to show distribution of Installs across all apps

# %%
# Chart - 5 visualization code

# Box plot to show distribution of Installs across all apps
sns.boxplot(x=apps_df["Installs"])

plt.title("Installs Distribution")

# Log scale compresses the huge range (10 to 1 billion) so both
# typical values and extreme outliers are visible on the same chart
plt.xscale('log')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Installs spans an extreme range (from single digits to 1 billion), so a raw box plot would be unreadable — applying a log scale compresses this range, making both typical values and outliers visible together.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most apps sit between 1,000 and 1,000,000 installs (the box). A small number of apps reach tens of millions, and an even smaller handful reach the 1 billion tier — these appear as extreme outliers, far outside the typical range.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * postitive impact This sets a realistic benchmark for new apps — reaching 1,000 to 1,000,000 installs is the normal, achievable range most apps fall into, and should be the practical short-to-medium-term goal rather than expecting billion-scale success.
# * negative angle — expecting rapid, massive scale (millions to billions) is unrealistic for the vast majority of apps; only a tiny fraction of apps ever reach that tier, so business plans and investor expectations should be grounded in the "typical app" range, not the rare outlier success stories.

# %% [markdown]
# #### Chart - 6 Rating Distribution by Top 10 Categories (Numerical-Categorical)

# %%
# Chart - 6 visualization code
# Get the names of the top 10 categories by number of apps
top_cats=apps_df['Category'].value_counts().head(10).index

# Filter the dataset to keep only rows belonging to these top 10 categories
subset=apps_df[apps_df['Category'].isin(top_cats)]
plt.figure(figsize=(12,6))
sns.boxplot(x='Category',y='Rating',data=subset)
plt.xticks(rotation=90)
plt.title('Rating Distibution by top 10 catgoreies')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Category is categorical and Rating is numerical, so a box plot lets us compare Rating's spread and outliers across multiple categories side by side — more informative than just comparing averages.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Ratings cluster tightly between 4.0-4.5 across nearly all top 10 categories, showing Category has little effect on typical Rating. However, almost every category has some lower outliers — a handful of apps rated unusually poorly compared to their peers. BUSINESS has 2 upper outliers and PERSONALIZATION has 1, meaning a few apps in these categories achieve exceptionally high ratings, standing out even among already strong performers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * since most apps across every major category achieve decent ratings (4.0-4.5), entering any of these categories doesn't inherently doom an app to poor reception; the "typical" outcome is good.
#  * Negative/risk angle — the consistent presence of lower outliers in nearly every category shows that good ratings are not guaranteed just by being in a popular category — quality execution still matters, since some apps in every category still underperform badly. This means category choice alone isn't a safety net; a business still needs to focus on core app quality regardless of which category they pick.

# %% [markdown]
# #### Chart - 7 installs vs reviews

# %%
# Chart - 7 visualization code
plt.figure(figsize=(8,6))
# Scatter plot: each dot = one app, positioned by its Installs (x) and Reviews (y)
sns.scatterplot(x='Installs',y='Reviews',data=apps_df)

# Log scale on both axes - compresses the huge range (thousands to billions)
# so the relationship between the two variables is actually visible
plt.xscale('log')
plt.yscale('log')
plt.title('Installs vs Reviews')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Both Installs and Reviews are numerical, so a scatter plot (with Here:-log scale on both axes, since both variables span huge ranges) lets us see whether the two move together — one dot per app.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There's a clear positive relationship — apps with more installs generally also have more reviews. However, a small group of apps (around 4) fall outside this pattern, showing high installs but unusually low review counts, breaking from the overall trend.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * since Installs and Reviews move together for most apps, either number can serve as a rough proxy for overall app popularity/engagement when the other isn't available — useful for quick competitive benchmarking.
# * negative angle — the handful of apps with high installs but unusually low reviews are worth investigating specifically; this pattern could signal low user engagement (people installed but didn't care enough to review), a newly-viral app that hasn't accumulated reviews yet, or even inflated/bot install numbers — any of these would be a red flag a business should look into rather than assume installs alone guarantee genuine engagement.

# %% [markdown]
# #### Chart - 8 Distribution of Days_Since_Update(Univarite)

# %%
# Chart - 8 visualization code
plt.figure(figsize=(8,5))
sns.histplot(apps_df['Days_Since_Update'],bins=20,kde=True)
plt.title('Distribution of Days SInce Update')
plt.xlabel('Days SInce Update')
plt.ylabel('Number of Apps')
plt.show()

# %% [markdown]
# #####1. Why did you pick the specific chart?

# %% [markdown]
# Days_Since_Update is a continuous numeric variable, so a histogram shows how this "recency" measure is distributed across all apps.

# %% [markdown]
# #####2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The distribution is left-skewed, with most apps clustering around ~3,000 days and a tail stretching toward 5,500+ days. Important caveat: since this dataset was collected around 2018 and the calculation compares against today's date (2026), the absolute values are inflated by roughly 8 years — they don't represent real-world neglect. What's still meaningful is the relative spread: some apps were updated notably more recently than others within the dataset's own timeframe, and this relative difference is what would correlate with actual maintenance behavior if recalculated against the dataset's original collection date.

# %% [markdown]
# #####3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# This is primarily a data-integrity insight rather than a direct business recommendation — it highlights that any "recency" or "freshness" metric must always be calculated against the correct reference date (ideally the dataset's collection date, not the analysis date) to be meaningful. For a business applying this kind of feature to their own live app data, this same metric (days since last update) would be a genuinely useful way to flag stale, potentially neglected apps in real time — as long as it's measured against the current date on live, current data rather than a historical snapshot.

# %% [markdown]
# ####Chart - 9 Days_Since_Update vs Rating (Numerical-Numerical)

# %%
# Chart - 9 visualization code
plt.figure(figsize=(12,6))
sns.scatterplot(x='Days_Since_Update',y='Rating',data=apps_df)
plt.title('Days Since Update vs Rating')
plt.show()

# %% [markdown]
# #####1. Why did you pick the specific chart?

# %% [markdown]
# Both Days_Since_Update and Rating are numerical, so a scatter plot shows whether apps updated more recently (relatively) tend to have different rating scores than apps updated longer ago.

# %% [markdown]
# #####2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Ratings span the full 1-5 range regardless of where an app falls in the Days_Since_Update cluster (mostly 3,000-4,500 days, as noted in Chart 16). There's no visible pattern suggesting recently-updated apps score meaningfully higher or lower than less recently-updated ones — this matches the earlier Correlation Heatmap finding, where Rating showed near-zero correlation with the other numeric factors.

# %% [markdown]
# #####3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# This tells a business that simply updating an app frequently doesn't automatically translate into a better rating score — update recency alone isn't a lever for improving Rating. This reinforces the earlier conclusion (from Chart 14) that Rating is likely driven more by qualitative factors — actual app quality, bug-free performance, and what users say in reviews — rather than structural/behavioral metrics like update frequency.

# %% [markdown]
# #### Chart - 10 Sentiment_Polarity vs Sentiment_Subjectivity (Numerical-Numerical, using reviews_df)

# %%
# Chart - 10 visualization code
plt.figure(figsize=(12,6))
sns.scatterplot(x='Sentiment_Subjectivity', y='Sentiment_Polarity', data=reviews_df)
plt.title('Sentiment polarity vs sentiment subjectivity')
plt.show()

# %% [markdown]
# #####1. Why did you pick the specific chart?

# %% [markdown]
# Both Sentiment_Polarity and Sentiment_Subjectivity are numerical scores from the review sentiment analysis, so a scatter plot shows how these two measures relate to each other across all reviews.

# %% [markdown]
# #####2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The data forms a fan/triangle shape — at low Subjectivity (factual, objective reviews), Polarity values cluster tightly near 0 (neutral sentiment). At high Subjectivity (strongly opinionated reviews), Polarity spreads across the full range, from strongly negative to strongly positive. In other words, factual-sounding reviews rarely carry strong sentiment, while opinionated reviews are the ones capable of extreme positive or negative sentiment.

# %% [markdown]
# #####3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# This tells a business that a review's Sentiment_Polarity score should be weighed alongside its Subjectivity score, not read in isolation. A strongly negative polarity score paired with high subjectivity represents a genuine, emotionally-charged complaint worth prioritizing. A strongly negative polarity score paired with low subjectivity is less common and, if it occurs, may reflect a real factual problem (e.g., "the app crashes every time") rather than an emotional overreaction — potentially an even more urgent, objective signal. This combination helps a business distinguish between emotional venting and genuine, factual product issues when triaging negative reviews.

# %% [markdown]
# #### Chart - 11 Type vs Content Rating

# %%
# Chart - 11 visualization code
# Set figure size for readability
plt.figure(figsize=(12,6))

# Crosstab: counts how many apps fall into each Type + Content Rating combination
crosstab=pd.crosstab(apps_df['Type'],apps_df['Content Rating'])

# Heatmap: color-codes the crosstab counts, annot=True shows exact numbers in each cell
sns.heatmap(crosstab,annot=True,fmt='d')
plt.title('type vs Content rating')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Both Type and Content Rating are categorical, so a crosstab counts how many apps fall into each combination, and a heatmap visualizes those counts with color for quick pattern recognition.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# "Everyone" content rating dominates overwhelmingly in both Free (7,248 apps) and Paid (655 apps) — the pattern is nearly identical regardless of pricing model. Adults only 18+ has just 3 apps in the Free category and 0 in Paid — meaning explicit adult-content apps are extremely rare on the platform overall, and none exist as Paid apps at all.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This is mostly a neutral/confirming insight — it shows content rating strategy doesn't meaningfully change based on pricing model; "Everyone" is the dominant, safe choice regardless of Free or Paid. The near-total absence of Adult 18+ content (3 apps total, 0 Paid) suggests this is either a heavily restricted/discouraged content category on the platform, or simply a content type with very little developer interest — not something a mainstream app strategy would typically target either way.

# %% [markdown]
# #### Chart - 12 Category vs type(top 10 Categories)

# %%
# Chart - 12 visualization code
top_cats=apps_df['Category'].value_counts().head(10).index
subset2=apps_df[apps_df['Category'].isin(top_cats)]
crosstab2=pd.crosstab(subset2['Type'],subset2['Category'])
plt.figure(figsize=(12,6))
sns.heatmap(crosstab2,annot=True,fmt='d',cmap='Greens')
plt.title('Category vs Type (Top 10 Categories)')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Both Category and Type are categorical, so a crosstab counts app combinations, and a heatmap visualizes the pattern with color.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# FAMILY dominates in raw counts for both Free (1,648) and Paid (183) apps. But looking at proportions, MEDICAL (21% Paid) and PERSONALIZATION (21.5% Paid) have roughly double the Paid-app percentage compared to FAMILY (10%), GAME (~8.5%), and TOOLS (9.4%).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Positive angle — MEDICAL and PERSONALIZATION show users are more willing to pay in these categories, suggesting these niches may support a paid pricing model better than mass-market categories like FAMILY or GAME, where free-with-ads is clearly the dominant strategy.
# * Risk/consideration angle — a business shouldn't assume "Free is always the safe default" across every category; category-specific user willingness-to-pay should guide pricing strategy, since a Paid MEDICAL app aligns with user expectations far better than a Paid FAMILY or GAME app would.

# %% [markdown]
# #### Chart - 13 Reviews vs Rating

# %%
# Chart - 13 visualization code
plt.figure(figsize=(12,6))
sns.scatterplot(x='Reviews',y='Rating',data=apps_df)
plt.xscale('log')
plt.title('Reviews vs Rating')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Both Reviews and Rating are numerical, so a scatter plot (with log scale on Reviews, since it spans an enormous range) shows whether review volume relates to rating patterns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Apps with very few reviews show scattered, extreme ratings (both very high and very low) — a small number of reviewers can easily produce an average of 1.0 or 5.0. Apps with a large number of reviews consistently settle into the 3.0+ range, since averaging across many reviewers naturally smooths out extreme opinions and converges toward a more realistic rating.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  A high or low Rating on an app with very few reviews should not be trusted as a reliable signal of quality; a business evaluating competitor apps or considering acquisition/benchmarking should weight ratings by review volume, not take the star average at face value alone. Positive angle — once an app accumulates a large review base, its rating becomes a much more trustworthy, stable indicator of real user sentiment — useful for a business to know when their own app's rating has become a "reliable" metric versus still being noisy due to low sample size.

# %% [markdown]
# #### Chart - 14 Sentiment_Polarity by Type (Free vs Paid) — Numerical-Categorical, using merged_df

# %%
# Chart - 14 visualization code
plt.figure(figsize=(12,6))
sns.boxplot(x='Type',y='Sentiment_Polarity',data=merged_df)
plt.title('Sentiment POlarity by type(free vs paid)')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Sentiment_Polarity is numerical and Type is categorical, so a box plot compares the spread of review sentiment between Free and Paid apps. This required merged_df, since Sentiment_Polarity comes from reviews_df and Type comes from apps_df.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Both Free and Paid apps show a similar sentiment polarity range (roughly 0.2 to 0.5, mildly positive), with Free apps showing more low-end outliers and Paid apps showing a few high-end outliers. Overall, review sentiment doesn't differ meaningfully by pricing model.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This confirms and reinforces our earlier Chart 3 finding — where average Rating was nearly identical between Free (4.29) and Paid (4.30) apps. Now we see the same pattern holds true at the review sentiment level too: users don't write more positive or more critical reviews just because they paid for an app. This strengthens the conclusion that pricing model isn't a meaningful driver of user satisfaction — whether measured by star rating or by actual review sentiment, the outcome is consistent, giving a business confidence that switching between Free and Paid strategies is unlikely to change how satisfied users feel about the app itself.

# %% [markdown]
# #### Chart - 15 Category vs Sentiment (Categorical-Categorical, using merged_df)

# %%
# Chart - 15 visualization code
subset3=merged_df[merged_df['Category'].isin(top_cats)]
crosstab3_pct = pd.crosstab(subset3['Category'], subset3['Sentiment'], normalize='index') * 100

plt.figure(figsize=(10,8))
sns.heatmap(crosstab3_pct, annot=True, fmt='.1f', cmap='Oranges')
plt.title('Category vs Sentiment (% within each Category)')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Both Category and Sentiment are categorical, so a crosstab with normalize='index' (converting counts to percentages within each category) combined with a heatmap lets us fairly compare sentiment patterns across categories, regardless of how many total reviews each category has.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most categories show a fairly balanced sentiment mix, but GAME stands out — it has the highest Negative sentiment percentage (35.5%) of any top category, alongside a strong Positive share too, but a notably low Neutral percentage (5%). This means GAME reviewers rarely feel indifferent — they tend to react strongly, either loving or disliking an app, rather than feeling lukewarm. In contrast, PERSONALIZATION (69.4%) and MEDICAL (68.3%) show strong Positive sentiment with more balanced, less extreme reactions overall.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# GAME developers should expect polarized, emotionally strong user reactions rather than mild/neutral feedback; this means review management (responding quickly to negative feedback, monitoring sentiment closely) is more critical in GAME than in more "steady" categories like MEDICAL, where user reactions are more consistently positive and less volatile. Positive angle — the flip side of this polarization is that GAME apps also have strong potential for high positive sentiment and enthusiastic word-of-mouth if the product genuinely resonates, since users clearly aren't shy about expressing strong opinions in either direction.

# %% [markdown]
# ####chart - 16 Top 10 Genres vs Content Rating (Categorical-Categorical)

# %%
# Chart - 16 visualization code
top_genres = apps_df['Genres'].value_counts().head(10).index
subset4 = apps_df[apps_df['Genres'].isin(top_genres)]
crosstab4 = pd.crosstab(subset4['Genres'], subset4['Content Rating'])

plt.figure(figsize=(12,8))
sns.heatmap(crosstab4, annot=True, fmt='d', cmap='Purples')
plt.title('Top 10 Genres vs Content Rating')
plt.show()

# %% [markdown]
# #####1. Why did you pick the specific chart?

# %% [markdown]
# Both Genres and Content Rating are categorical, so a crosstab + heatmap lets us compare how content classifications distribute across the most common genres.

# %% [markdown]
# #####2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Under "Everyone" content rating, TOOLS dominates (818 apps), followed by EDUCATION (484) and BUSINESS (405). Under "Teen," ENTERTAINMENT dominates (138), followed by PERSONALIZATION (51) — showing a clear shift: Everyone-rated apps skew toward practical/utility genres (Tools, Education, Business), while Teen-rated apps skew toward more engagement/entertainment-driven genres.

# %% [markdown]
# This suggests that genre and target content rating naturally align — a TOOLS or EDUCATION app aiming for the broadest audience (Everyone) fits the existing market pattern well, while an ENTERTAINMENT-focused app naturally trends toward a Teen audience. Risk/consideration angle — this pattern reflects what's common, not what's guaranteed to succeed; simply building a TOOLS app under "Everyone" doesn't ensure success just because it matches the dominant pattern — genre-content alignment is a starting point, not a substitute for app quality or differentiation.

# %% [markdown]
# #####3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# #### Chart - 17 Installs vs Rating, colored by Type (Free/Paid)

# %%
# Chart - 17 visualization code
plt.figure(figsize=(12,6))
sns.scatterplot(x='Installs',y='Rating',hue='Type',data=apps_df)
plt.xscale('log')
plt.title('Installs vs Rating,colured by hue')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Installs and Rating are both numerical, and adding Type (Free/Paid) as a 3rd variable via hue lets us see whether the Installs-Rating relationship differs between pricing models — this is what makes it Multivariate rather than just Bivariate.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Paid apps cluster almost entirely in the lower install ranges (below ~100,000), with essentially no Paid apps reaching the highest install tiers. Free apps, by contrast, span the entire range — including the massive 100M-1B install tier where all the top-performing apps sit.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Positive angle — this strongly suggests that reaching mass-scale adoption (tens of millions to billions of installs) is realistically only achievable through a Free pricing model; Free removes the biggest barrier to entry (upfront cost), letting an app spread far more widely.
# * Risk/consideration angle — this doesn't mean Free apps are automatically successful (most Free apps still sit in modest install ranges, as we saw in Chart 5) — but it does mean a business aiming specifically for viral, mass-market reach should treat Paid pricing as a structural ceiling that likely blocks that scale of growth, regardless of app quality

# %% [markdown]
# ####chart - 18 Sentiment_Polarity by Category, split by Type (Multivariate)

# %%
 #Chart - 13 visualization code
 top_cats=apps_df['Category'].value_counts().head(10).index
subset5 = merged_df[merged_df['Category'].isin(top_cats)]
plt.figure(figsize=(14,7))
sns.boxplot(x='Category', y='Sentiment_Polarity', hue='Type', data=subset5)
plt.xticks(rotation=90)
plt.title('Sentiment Polarity by Category and Type')
plt.show()

# %% [markdown]
# #####1 Why did you pick the specific chart?

# %% [markdown]
# Combining Category (top 10), Sentiment_Polarity (numerical), and Type (Free/Paid via hue) in one box plot lets us check whether sentiment patterns across categories differ by pricing model — this is what makes it Multivariate.

# %% [markdown]
# #####2. What is/are the insight(s) found from the chart?

# %% [markdown]
# For several categories — LIFESTYLE, PRODUCTIVITY, BUSINESS, TOOLS, and FINANCE — no Paid-app sentiment data appears at all in this merged view. This is most likely a small sample size issue, not a real absence of sentiment: Paid apps are already a small minority within each category (roughly 8-10%, from Chart 9), and after further filtering to only reviews with actual sentiment text (~58% of reviews, since ~42% have no text), the number of Paid apps with usable sentiment data in these specific categories drops to zero or near-zero in this dataset.

# %% [markdown]
# #####3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# This is primarily a data limitation insight rather than a business conclusion — it's a caution against assuming "Paid apps in these categories have no sentiment signal," when the real explanation is simply insufficient sample size in this dataset. For a business with access to their own live, larger-scale data, this same comparison would likely reveal real Paid-app sentiment patterns once enough reviews accumulate — the takeaway here is to always check sample size before drawing conclusions from a group comparison, especially when one group (Paid apps with reviews) is inherently rare.

# %% [markdown]
# #### Chart - 19 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
plt.figure(figsize=(12,6))
sns.heatmap(apps_df[['Rating','Reviews','Installs','Price','Size']].corr(),annot=True,cmap='coolwarm')
plt.title('Correlation heatmap-Numerical variables')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Rating, Reviews, Installs, Price, and Size are all numerical columns, so a correlation heatmap gives an overview of all pairwise relationships at once, instead of building many separate scatter plots.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The only meaningfully strong relationship is between Reviews and Installs (0.625) — confirming what we saw visually in Chart 7. Every other pair — Rating vs Reviews, Rating vs Installs, Rating vs Price, Rating vs Size — shows correlation near 0, meaning none of these numeric factors have a simple straight-line relationship with Rating.

# %% [markdown]
# #####3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# This is a genuinely important finding — it tells a business that Rating isn't explained by any of the "easy" numeric factors (how big the app is, how much it costs, how many installs/reviews it has). This means chasing more installs or lowering price won't automatically improve ratings. What actually drives a good rating is more likely rooted in qualitative factors — app quality, user experience, bug-free performance, and the actual content of what users say in reviews (sentiment, specific complaints) — not something visible in these structural numeric columns alone. This justifies why sentiment analysis on review text (which we explored earlier with merged_df) is genuinely necessary, not optional, for understanding what really drives user satisfaction.

# %% [markdown]
# #### Chart - 20- Rating, Reviews, Installs by Type(Multivariate)

# %%
# Pair Plot visualization code
sns.pairplot(apps_df[['Rating', 'Reviews', 'Installs', 'Type']], hue='Type')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot shows scatter plots for every pair of numeric variables (Rating, Reviews, Installs) at once, with Type (Free/Paid) color-coded via hue — giving a single combined view of multiple relationships and how they differ by pricing model, rather than building each one separately.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The Reviews-Installs relationship (already confirmed as strongly correlated in Chart 14) holds across the grid, but the extreme outliers — apps reaching massive Reviews and Installs numbers — are exclusively Free type apps. No Paid apps appear at these extreme high-end values.

# %% [markdown]
# #####3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# This directly confirms and reinforces the finding from Chart 13 — mass-scale adoption (extremely high installs and reviews) is a pattern seen only in Free apps, never Paid ones. For a business, this strengthens the conclusion that a Free pricing strategy is the only realistic path to reaching viral, top-tier scale, while Paid apps should expect and plan around a smaller, more contained user base rather than aiming for mass-market dominance.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Based on the insights from this analysis, here's what I'd suggest to a client trying to succeed on the Google Play Store:
#
#
# *  Default to Free pricing, not Paid — Free apps dominate the platform and are the only ones reaching mass-scale adoption; pricing showed almost no effect on ratings or sentiment.
#
# *  If entering GAME specifically, expect high competition (959+ apps) — differentiation and quality matter more here; GAME users react strongly (positive or negative), so active engagement and quick fixes are critical to avoid negative sentiment tipping the balance.
#
# *  Avoid SOCIAL/COMMUNICATION as a growth target unless prepared for a long fight — it's a winner-take-all space already dominated by a few giant apps.
# *   Don't judge quality by star rating alone — Rating showed no real correlation with installs, reviews, price, or size; actual quality signals live in review text.
#
# *  Read and act on review sentiment, not just the star average — negative-sounding reviews often still come from satisfied users flagging one fixable issue.
#
# * Distrust ratings from apps with very few reviews — small sample sizes produce unreliable, extreme ratings.
#
# *   Consider Paid/freemium models in niche categories like MEDICAL or PERSONALIZATION, where users show higher willingness to pay.
#
# *  Set realistic growth targets — only ~0.2% of apps ever reach 1 billion installs; plan around the achievable 1M–10M range instead.
#
# * Keep the app updated regularly — using Days_Since_Update, stale apps can be flagged and prioritized for maintenance to stay competitive.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# *  Rating shows almost no correlation with Reviews, Installs, Price, or Size — none of these four factors can be used to predict an app's rating/quality.
#
# *   Reviews and Installs are strongly correlated (0.625) — apps with more installs consistently accumulate more reviews.
#
# *   Free and Paid apps show no meaningful difference in Rating or Sentiment Polarity — pricing model does not affect user satisfaction.
#
# *   Paid apps never reach the highest install tiers (100M+) — mass-scale adoption is exclusive to Free apps.
# *   Apps with very few reviews show extreme, unreliable ratings; ratings stabilize toward 3.0+ only once review volume grows large.
#
#
# *  GAME category shows unusually polarized sentiment — high Positive and high Negative percentages, with very low Neutral — unlike more evenly-satisfied categories like MEDICAL.
#
#
# *   MEDICAL and PERSONALIZATION show roughly double the proportion of Paid apps (21%) compared to mass-market categories like FAMILY or GAME (~9%), suggesting higher willingness to pay in niche categories.
#
#
# *   SOCIAL has very few apps (239) but by far the highest average installs, skewed heavily by a handful of dominant apps (Facebook, Instagram, WhatsApp) — not representative of a typical SOCIAL app's performance.
# * Only about 0.2% of apps ever reach 1 billion installs — the vast majority of apps sit in the 1,000–1,000,000 install range.Rating shows almost no correlation with Reviews, Installs, Price, or Size — none of these four factors can be used to predict an app's rating/quality.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
